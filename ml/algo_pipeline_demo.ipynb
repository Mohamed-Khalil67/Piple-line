# %%
from model import DataManager
from utils.utils import ModelBuilder

# %%
X_train, X_test, y_train, y_test = DataManager()
m = ModelBuilder('.') # model_path directory
m.train(X_train, y_train)
m.print_accuracy(X_train,y_train)
print(m)
m.save_model()
# Out:
# Start Data Managing
#  - - - Start Data Processing - - -
# _ _ Fetch Data From bucket _ _
#  - - - Start Data Merging - - -
#  - - - data merged - - -
#      listing_id  local_price  Unnamed: 0  \
# 0         56093   170.000000          12
# 1         57207    49.952756          13
# 2        114543   107.374026          19
# 3        149534   169.000000           9
# 4        164255    75.876209          28
# ..          ...          ...         ...
# 994    28684174   725.175781         662
# 995    28709644   475.000000         745
# 996    28751412   117.000000          88
# 997    28774896   156.397468         159
# 998    28792796    49.184211         998
#
#                                                   name          type   city  \
# 0                          Beau duplex dans le Marais    entire_home  Paris
# 1                             Belle Chambre pour court  private_room  Paris
# 2                    Charming 1bdr 55m² - Eiffel Tower   entire_home  Paris
# ...

# %% [markdown]
# Commentaires Sur l'algolrithme de Datamanging et ModelBuilding :
#
# - Les Datas utilisées sont celles de price availability et pricing
# - De ce qu'on observe on a une accuracy de 37.35% :
#     - ce qui pas bien par rapport aux paramtres utlisées avec y
#     - on aura une meilleur accuracy avec plus de parametres à utiliser ,
#     - les paramétres utilisées ici : prenant local_price comme y et les X [beds, bedrooms , bathrooms , person_capacity]
# - C'est semblant Balanced ni underfitting mais surement ni overfitting
